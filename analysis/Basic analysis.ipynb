# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import spacy
from spacy.lang.en import stop_words
from collections import Counter
from tqdm import tqdm
import numpy as np

plt.style.use("ggplot")

# %%
import string

# %% [markdown]
# # Data understanding

# %%
df1 = pd.read_csv("../data/result/final/train2.tsv", sep="\t")
df2 = pd.read_csv("../data/result/final/test2.tsv", sep="\t")
df3 = pd.read_csv("../data/result/final/val2.tsv", sep="\t")

# %%
df = pd.concat([df1, df2, df3], axis=0, ignore_index=True)

# %%
df.head(2)
# Out:
#       json_id      label                                          statement  \
# 0   2635.json      false  Says the Annies List political group supports ...
# 1  10540.json  half-true  When did the decline of coal start? It started...
#
#                               subject         speaker             job_title  \
# 0                            abortion    dwayne-bohac  State representative
# 1  energy,history,job-accomplishments  scott-surovell        State delegate
#
#       state party_affiliation  barely_true_counts  false_counts  ...  \
# 0     Texas        republican                 0.0           1.0  ...
# 1  Virginia          democrat                 0.0           0.0  ...
#
#    sentiment      question  grammar_errors ratio_of_capital_letters  \
# 0   negative  not_question               1                     3.66
# 1    neutral      question               1                     4.26
#
#        curse  emotion       gibberish  offensiveness  political_bias  \
# 0  non-curse  disgust  mild gibberish  non-offensive          CENTER
# 1  non-curse  neutral           clean  non-offensive           RIGHT
#
#                                             articles
# 0  The recent statement from the Annies List poli...
# 1  The era of coal's dominance is waning, a reali...
#
# [2 rows x 25 columns]

# %%
print(df[df["json_id"]=='1626.json']['statement'].values[0])
# Out:
# Joe, I keep hearing you every morning talking about the biggest tax increase in history, but you don't mention it's also the biggest tax cut in history.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12836 entries, 0 to 12835
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   json_id                   12836 non-null  object
#  1   label                     12836 non-null  object
#  2   statement                 12836 non-null  object
#  3   subject                   12836 non-null  object
#  4   speaker                   12836 non-null  object
#  5   job_title                 9260 non-null   object
#  6   state                     10082 non-null  object
#  7   party_affiliation         12836 non-null  object
#  8   barely_true_counts        12836 non-null  float64
#  9   false_counts              12836 non-null  float64
#  10  half_true_counts          12836 non-null  float64
#  11  mostly_true_counts        12836 non-null  float64
#  12  pants_on_fire_counts      12836 non-null  float64
#  13  context                   12707 non-null  object
#  14  justification             12692 non-null  object
#  15  sentiment                 12836 non-null  object
#  16  question                  12836 non-null  object
#  17  grammar_errors            12836 non-null  int64
#  18  ratio_of_capital_letters  12836 non-null  float64
#  19  curse                     12836 non-null  object
#  20  emotion                   12836 non-null  object
#  21  gibberish                 12836 non-null  object
#  22  offensiveness             12836 non-null  object
#  23  political_bias            12836 non-null  object
#  24  articles                  12828 non-null  object
# dtypes: float64(6), int64(1), object(18)
# memory usage: 2.4+ MB

# %% [markdown]
# # Data preparation

# %%
df[["statement", "justification"]] = df[["statement", "justification"]].astype(str)

# %% [markdown]
# ## Add statement and justification length information

# %%
df["statement_len"] = df["statement"].apply(len)
df["justification_len"] = df["justification"].apply(len)

# %% [markdown]
# ## Add word count

# %%
df["statement_wc"] = df["statement"].apply(lambda x: len(x.split(" ")))
df["justification_wc"] = df["justification"].apply(lambda x: len(x.split(" ")))
df["articles_wc"] = df["articles"].apply(lambda x: len(str(x).split(" ")))

# %%
df[df["articles"].isna()][["label", "statement", "context", "articles"]]
# Out:
#              label                                          statement  \
# 2051   barely-true  Says Will Hurd said a border-long U.S.-Mexico ...
# 4061   barely-true  In Jeanne Shaheen, New Hampshire has a Senator...
# 4922         false                          Mitt Romney has 15 homes.
# 7300         false  I balanced the budget for four straight years,...
# 7500   mostly-true  Says Donald Trump believes that states should ...
# 8298    pants-fire  Says a man opted out of Obamacare after the ma...
# 9183     half-true  Says weve accomplished balancing two budgets w...
# 12728         true  Claims Ohio Gov. John Kasich says climate chan...
#
#                                                  context articles
# 2051             a TV ad pointed out to PolitiFact Texas      NaN
# 4061                                            an email      NaN
# 4922          the video, "When Mitt Romney Came to Town"      NaN
# 7300   a Republican presidential debate in Sioux City...      NaN
# 7500      a speech at the Democratic National Convention      NaN
# 8298                         viral posts on the Internet      NaN
# 9183                                            a video       NaN
# 12728                                a billboard message      NaN

# %%
df = df.drop(["json_id"], axis=1)

# %%
df.head(2)
# Out:
#        label                                          statement  \
# 0      false  Says the Annies List political group supports ...
# 1  half-true  When did the decline of coal start? It started...
#
#                               subject         speaker             job_title  \
# 0                            abortion    dwayne-bohac  State representative
# 1  energy,history,job-accomplishments  scott-surovell        State delegate
#
#       state party_affiliation  barely_true_counts  false_counts  \
# 0     Texas        republican                 0.0           1.0
# 1  Virginia          democrat                 0.0           0.0
#
#    half_true_counts  ...  emotion       gibberish  offensiveness  \
# 0               0.0  ...  disgust  mild gibberish  non-offensive
# 1               1.0  ...  neutral           clean  non-offensive
#
#   political_bias                                           articles  \
# 0         CENTER  The recent statement from the Annies List poli...
# 1          RIGHT  The era of coal's dominance is waning, a reali...
#
#   statement_len  justification_len  statement_wc justification_wc articles_wc
# 0            82                248            11               40         205
# 1           141                637            24              105         220
#
# [2 rows x 29 columns]

# %% [markdown]
# ## Add two-way label

# %%
df["bin_label"] = df["label"].apply(lambda x: "true" if x in ["half-true", "mostly-true", "true"] else "false")

# %% [markdown]
# ## Label as a score

# %%
score = {
    "pants-fire": -3,
    "false": -2,
    "barely-true": -1,
    "half-true": 1,
    "mostly-true": 2,
    "true": 3
}
df["label_score"] = df["label"].apply(lambda x: score[x])

# %% [markdown]
# ## Add punctuations count per 100 characters

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
df["punctuations"] = df["statement"].apply(lambda s: sum(map(s[:100].count, string.punctuation)))

# %% [markdown]
# ## How many null values

# %%
df.isna().sum()
# Out:
# label                          0
# statement                      0
# subject                        0
# speaker                        0
# job_title                   3576
# state                       2754
# party_affiliation              0
# barely_true_counts             0
# false_counts                   0
# half_true_counts               0
# mostly_true_counts             0
# pants_on_fire_counts           0
# context                      129
# justification                  0
# sentiment                      0
# question                       0
# grammar_errors                 0
# ratio_of_capital_letters       0
# curse                          0
# emotion                        0
# gibberish                      0
# offensiveness                  0
# political_bias                 0
# articles                       8
# statement_len                  0
# justification_len              0
# statement_wc                   0
# justification_wc               0
# articles_wc                    0
# bin_label                      0
# label_score                    0
# punctuations                   0
# dtype: int64

# %% [markdown]
# ## Describe dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12836 entries, 0 to 12835
# Data columns (total 32 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   label                     12836 non-null  object
#  1   statement                 12836 non-null  object
#  2   subject                   12836 non-null  object
#  3   speaker                   12836 non-null  object
#  4   job_title                 9260 non-null   object
#  5   state                     10082 non-null  object
#  6   party_affiliation         12836 non-null  object
#  7   barely_true_counts        12836 non-null  float64
#  8   false_counts              12836 non-null  float64
#  9   half_true_counts          12836 non-null  float64
#  10  mostly_true_counts        12836 non-null  float64
#  11  pants_on_fire_counts      12836 non-null  float64
#  12  context                   12707 non-null  object
#  13  justification             12836 non-null  object
#  14  sentiment                 12836 non-null  object
#  15  question                  12836 non-null  object
#  16  grammar_errors            12836 non-null  int64
#  17  ratio_of_capital_letters  12836 non-null  float64
#  18  curse                     12836 non-null  object
#  19  emotion                   12836 non-null  object
#  20  gibberish                 12836 non-null  object
#  21  offensiveness             12836 non-null  object
#  22  political_bias            12836 non-null  object
#  23  articles                  12828 non-null  object
#  24  statement_len             12836 non-null  int64
#  25  justification_len         12836 non-null  int64
#  26  statement_wc              12836 non-null  int64
#  27  justification_wc          12836 non-null  int64
#  28  articles_wc               12836 non-null  int64
#  29  bin_label                 12836 non-null  object
#  30  label_score               12836 non-null  int64
#  31  punctuations              12836 non-null  int64
# dtypes: float64(6), int64(8), object(18)
# memory usage: 3.1+ MB

# %%
df.describe()
# Out:
#        barely_true_counts  false_counts  half_true_counts  mostly_true_counts  \
# count        12836.000000  12836.000000      12836.000000        12836.000000
# mean            11.595980     13.369975         17.218838           16.526955
# std             18.996727     24.150879         35.910604           36.225691
# min              0.000000      0.000000          0.000000            0.000000
# 25%              0.000000      0.000000          0.000000            0.000000
# 50%              2.000000      2.000000          3.000000            3.000000
# 75%             12.000000     15.000000         13.000000           12.000000
# max             70.000000    114.000000        160.000000          163.000000
#
#        pants_on_fire_counts  grammar_errors  ratio_of_capital_letters  \
# count          12836.000000    12836.000000              12836.000000
# mean               6.246261        0.381505                  3.685870
# std               16.162788        0.671460                  2.684403
# min                0.000000        0.000000                  0.000000
# 25%                0.000000        0.000000                  1.890000
# 50%                1.000000        0.000000                  3.170000
# 75%                5.000000        1.000000                  4.760000
# max              105.000000        7.000000                 82.140000
#
#        statement_len  justification_len  statement_wc  justification_wc  \
# count   12836.000000       12836.000000  12836.000000      12836.000000
# mean      106.286460         426.692350     17.914693         72.078140
# std        45.013247         309.836223      7.748308         64.631191
# min        11.000000           3.000000      2.000000          1.000000
# 25%        73.000000         272.000000     12.000000         46.000000
# 50%        99.000000         395.000000     17.000000         67.000000
# 75%       133.000000         537.000000     22.000000         90.000000
# max       395.000000        9394.000000     66.000000       3030.000000
#
#         articles_wc   label_score  punctuations
# count  12836.000000  12836.000000  12836.000000
# mean     211.624961      0.271035      1.937831
# std       14.801490      2.007545      1.535514
# min        1.000000     -3.000000      0.000000
# 25%      208.000000     -2.000000      1.000000
# 50%      214.000000      1.000000      2.000000
# 75%      219.000000      2.000000      3.000000
# max      239.000000      3.000000     16.000000

# %%
df['statement_word_count'] = df['statement_wc']
df['justification_word_count'] = df['justification_wc']
df['articles_word_count'] = df['articles_wc']

# %%
df[['statement_word_count', 'justification_word_count', 'articles_word_count']].describe()
# Out:
#        statement_word_count  justification_word_count  articles_word_count
# count          12836.000000              12836.000000         12836.000000
# mean              17.914693                 72.078140           211.624961
# std                7.748308                 64.631191            14.801490
# min                2.000000                  1.000000             1.000000
# 25%               12.000000                 46.000000           208.000000
# 50%               17.000000                 67.000000           214.000000
# 75%               22.000000                 90.000000           219.000000
# max               66.000000               3030.000000           239.000000

# %%
df.describe().to_csv("describtion.csv", float_format="%.3f")

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.duplicated(subset=["statement"]).sum()
# Out:
# 26

# %%
df[df.duplicated(subset=["statement"])]
# Out:
#              label                                          statement  \
# 1014     half-true                                        On abortion
# 1826         false                       On support for gay marriage.
# 1858         false  Obama says Iran is a 'tiny' country, 'doesn't ...
# 2710         false                    On repealing the 17th Amendment
# 2859   mostly-true  Four balanced budgets in a row, with no new ta...
# 3269         false                           On a cap-and-trade plan.
# 4399         false                  On the Trans-Pacific Partnership.
# 4852     half-true  During Sherrod Browns past decade as a D.C. po...
# 4953         false  On changing the rules for filibusters on presi...
# 6780     half-true                                        On torture.
# 6805         false              On support for the Export-Import Bank
# 7269     half-true                On the status of illegal immigrants
# 7676          true  Six justices on the U.S. Supreme Court have be...
# 8935          true         Says Mitt Romney flip-flopped on abortion.
# 9429     half-true          Twenty million Americans are out of work.
# 9671         false  On changing the rules for filibusters on presi...
# 9779   barely-true  Some 20,000 Delphi salaried retirees lost up t...
# 10363         true  Says Milken Institute rated San Antonio as nat...
# 10867        false                                    On Common Core.
# 11454        false                           On a cap-and-trade plan.
# 11543    half-true                              On offshore drilling.
# 11629        false                 Social Security is a Ponzi scheme.
# 11709        false                                On high-speed rail.
# 11990        false           Martin Luther King Jr. was a Republican.
# 12028  mostly-true          Americans havent had a raise in 15 years.
# 12453        false  Signs letter saying Consumer Product Safety Co...
#
#                                                  subject             speaker  \
# 1014                       abortion,candidates-biography       charlie-crist
# 1826    civil-rights,families,gays-and-lesbians,marriage        barack-obama
# 1858                                      foreign-policy         john-mccain
# 2710                            debates,elections,states      david-dewhurst
# 2859   job-accomplishments,jobs,state-budget,state-fi...      chris-christie
# 3269            cap-and-trade,climate-change,environment        tim-pawlenty
# 4399                                               trade          pat-toomey
# 4852                    economy,job-accomplishments,jobs         josh-mandel
# 4953                                 congressional-rules     mitch-mcconnell
# 6780                              human-rights,terrorism       newt-gingrich
# 6805                                               trade      glenn-grothman
# 7269                                         immigration        scott-walker
# 7676                 congress,legal-issues,supreme-court          gwen-moore
# 8935                       abortion,message-machine-2012        jon-huntsman
# 9429                                                jobs          tom-marino
# 9671                                 congressional-rules        barack-obama
# 9779                                corporations,economy      michael-turner
# 10363                                            economy       julian-castro
# 10867                                          education        bobby-jindal
# 11454    cap-and-trade,climate-change,energy,environment         sarah-palin
# 11543                                             energy        barack-obama
# 11629                                    social-security          rick-perry
# 11709         federal-budget,state-budget,transportation           tom-petri
# 11990                             bipartisanship,history  charlotte-bergmann
# 12028                                       economy,jobs     hillary-clinton
# 12453  consumer-safety,government-regulation,public-s...    marsha-blackburn
#
#                                                job_title         state  \
# 1014                                                 NaN       Florida
# 1826                                           President      Illinois
# 1858                                        U.S. senator       Arizona
# 2710                                 Lieutenant governor         Texas
# 2859                              Governor of New Jersey    New Jersey
# 3269                                                 NaN           NaN
# 4399                           Candidate for U.S. Senate  Pennsylvania
# 4852                                      Ohio treasurer          Ohio
# 4953                              Senate minority leader      Kentucky
# 6780                        Co-host on CNN's "Crossfire"       Georgia
# 6805                        State Senator, 20th District     Wisconsin
# 7269                          Milwaukee County Executive     Wisconsin
# 7676                   U.S. House member -- 4th District     Wisconsin
# 8935                                                 NaN          Utah
# 9429                                 U.S. representative  Pennsylvania
# 9671                                           President      Illinois
# 9779   Representative from Ohio's 3rd Congressional D...          Ohio
# 10363                                 Mayor, San Antonio         Texas
# 10867                              Governor of Louisiana     Louisiana
# 11454                                                NaN        Alaska
# 11543                                          President      Illinois
# 11629                                           Governor         Texas
# 11709                  U.S. House member -- 6th District     Wisconsin
# 11990                                          Candidate     Tennessee
# 12028                             Presidential candidate      New York
# 12453                                U.S. Representative     Tennessee
#
#       party_affiliation  barely_true_counts  false_counts  half_true_counts  \
# 1014           democrat                15.0           9.0              20.0
# 1826           democrat                70.0          71.0             160.0
# 1858         republican                31.0          39.0              31.0
# 2710         republican                 8.0           8.0              10.0
# 2859         republican                10.0          17.0              27.0
# 3269         republican                 2.0           3.0               3.0
# 4399         republican                 3.0           2.0               2.0
# 4852         republican                 4.0           5.0               4.0
# 4953         republican                 7.0           6.0               5.0
# 6780         republican                16.0          15.0              20.0
# 6805         republican                 2.0           4.0               1.0
# 7269         republican                26.0          41.0              32.0
# 7676           democrat                 3.0           4.0               4.0
# 8935         republican                 5.0           1.0               5.0
# 9429         republican                 1.0           1.0               1.0
# 9671           democrat                70.0          71.0             160.0
# 9779         republican                 1.0           0.0               2.0
# 10363          democrat                 0.0           0.0               3.0
# 10867        republican                 0.0           1.0               4.0
# 11454        republican                 9.0          19.0               9.0
# 11543          democrat                70.0          71.0             160.0
# 11629        republican                30.0          30.0              42.0
# 11709        republican                 0.0           1.0               0.0
# 11990        republican                 0.0           2.0               0.0
# 12028          democrat                40.0          29.0              69.0
# 12453        republican                 2.0           2.0               1.0
#
#        ...  justification_len  statement_wc justification_wc articles_wc  \
# 1014   ...                394             2               64         219
# 1826   ...                494             5               83         227
# 1858   ...                732            12              116         212
# 2710   ...                359             5               60         210
# 2859   ...                450            38               74         211
# 3269   ...                290             4               45         197
# 4399   ...                315             4               61         219
# 4852   ...                708            36              117         207
# 4953   ...                856             9              144         213
# 6780   ...                412             2               64         214
# 6805   ...                534             6               93         193
# 7269   ...                569             6               88         222
# 7676   ...                413            16               62         215
# 8935   ...                441             6               74         217
# 9429   ...                628             7              113         211
# 9671   ...                376             9               72         218
# 9779   ...                302            22               47         214
# 10363  ...                130            11               21         185
# 10867  ...                648             3              101         216
# 11454  ...                470             4               85         215
# 11543  ...                297             3               51         210
# 11629  ...                205             6               36         218
# 11709  ...                282             3               51         194
# 11990  ...                390             7               68         211
# 12028  ...                304             8               51         219
# 12453  ...                480            22               79         218
#
#       bin_label label_score  punctuations  statement_word_count  \
# 1014       true           1             0                     2
# 1826      false          -2             1                     5
# 1858      false          -2             7                    12
# 2710      false          -2             0                     5
# 2859       true           2             3                    38
# 3269      false          -2             3                     4
# 4399      false          -2             2                     4
# 4852       true           1             3                    36
# 4953      false          -2             0                     9
# 6780       true           1             1                     2
# 6805      false          -2             1                     6
# 7269       true           1             0                     6
# 7676       true           3             2                    16
# 8935       true           3             2                     6
# 9429       true           1             1                     7
# 9671      false          -2             0                     9
# 9779      false          -1             1                    22
# 10363      true           3             2                    11
# 10867     false          -2             1                     3
# 11454     false          -2             3                     4
# 11543      true           1             1                     3
# 11629     false          -2             1                     6
# 11709     false          -2             2                     3
# 11990     false          -2             2                     7
# 12028      true           2             1                     8
# 12453     false          -2             0                    22
#
#       justification_word_count articles_word_count
# 1014                        64                 219
# 1826                        83                 227
# 1858                       116                 212
# 2710                        60                 210
# 2859                        74                 211
# 3269                        45                 197
# 4399                        61                 219
# 4852                       117                 207
# 4953                       144                 213
# 6780                        64                 214
# 6805                        93                 193
# 7269                        88                 222
# 7676                        62                 215
# 8935                        74                 217
# 9429                       113                 211
# 9671                        72                 218
# 9779                        47                 214
# 10363                       21                 185
# 10867                      101                 216
# 11454                       85                 215
# 11543                       51                 210
# 11629                       36                 218
# 11709                       51                 194
# 11990                       68                 211
# 12028                       51                 219
# 12453                       79                 218
#
# [26 rows x 35 columns]

# %%
df[df["statement"]=='On abortion']
# Out:
#           label    statement                           subject        speaker  \
# 709       false  On abortion  abortion,corrections-and-updates    mitt-romney
# 1014  half-true  On abortion     abortion,candidates-biography  charlie-crist
#
#             job_title          state party_affiliation  barely_true_counts  \
# 709   Former governor  Massachusetts        republican                34.0
# 1014              NaN        Florida          democrat                15.0
#
#       false_counts  half_true_counts  ...  justification_len  statement_wc  \
# 709           32.0              58.0  ...                508             2
# 1014           9.0              20.0  ...                394             2
#
#      justification_wc articles_wc bin_label label_score  punctuations  \
# 709               101         216     false          -2             0
# 1014               64         219      true           1             0
#
#       statement_word_count justification_word_count articles_word_count
# 709                      2                      101                 216
# 1014                     2                       64                 219
#
# [2 rows x 35 columns]

# %%
df[df["statement"]=='On torture.']
# Out:
#           label    statement                 subject        speaker  \
# 1071       true  On torture.                military    john-mccain
# 6780  half-true  On torture.  human-rights,terrorism  newt-gingrich
#
#                          job_title    state party_affiliation  \
# 1071                  U.S. senator  Arizona        republican
# 6780  Co-host on CNN's "Crossfire"  Georgia        republican
#
#       barely_true_counts  false_counts  half_true_counts  ...  \
# 1071                31.0          39.0              31.0  ...
# 6780                16.0          15.0              20.0  ...
#
#       justification_len  statement_wc justification_wc articles_wc bin_label  \
# 1071                513             2               91         216      true
# 6780                412             2               64         214      true
#
#      label_score  punctuations  statement_word_count justification_word_count  \
# 1071           3             1                     2                       91
# 6780           1             1                     2                       64
#
#      articles_word_count
# 1071                 216
# 6780                 214
#
# [2 rows x 35 columns]

# %%
df.duplicated(subset=["statement", "label"]).sum()
# Out:
# 20

# %%
df[df.duplicated(subset=["statement", "label"])]
# Out:
#              label                                          statement  \
# 1858         false  Obama says Iran is a 'tiny' country, 'doesn't ...
# 2710         false                    On repealing the 17th Amendment
# 3269         false                           On a cap-and-trade plan.
# 4399         false                  On the Trans-Pacific Partnership.
# 4852     half-true  During Sherrod Browns past decade as a D.C. po...
# 4953         false  On changing the rules for filibusters on presi...
# 6805         false              On support for the Export-Import Bank
# 7676          true  Six justices on the U.S. Supreme Court have be...
# 8935          true         Says Mitt Romney flip-flopped on abortion.
# 9429     half-true          Twenty million Americans are out of work.
# 9671         false  On changing the rules for filibusters on presi...
# 10363         true  Says Milken Institute rated San Antonio as nat...
# 10867        false                                    On Common Core.
# 11454        false                           On a cap-and-trade plan.
# 11543    half-true                              On offshore drilling.
# 11629        false                 Social Security is a Ponzi scheme.
# 11709        false                                On high-speed rail.
# 11990        false           Martin Luther King Jr. was a Republican.
# 12028  mostly-true          Americans havent had a raise in 15 years.
# 12453        false  Signs letter saying Consumer Product Safety Co...
#
#                                                  subject             speaker  \
# 1858                                      foreign-policy         john-mccain
# 2710                            debates,elections,states      david-dewhurst
# 3269            cap-and-trade,climate-change,environment        tim-pawlenty
# 4399                                               trade          pat-toomey
# 4852                    economy,job-accomplishments,jobs         josh-mandel
# 4953                                 congressional-rules     mitch-mcconnell
# 6805                                               trade      glenn-grothman
# 7676                 congress,legal-issues,supreme-court          gwen-moore
# 8935                       abortion,message-machine-2012        jon-huntsman
# 9429                                                jobs          tom-marino
# 9671                                 congressional-rules        barack-obama
# 10363                                            economy       julian-castro
# 10867                                          education        bobby-jindal
# 11454    cap-and-trade,climate-change,energy,environment         sarah-palin
# 11543                                             energy        barack-obama
# 11629                                    social-security          rick-perry
# 11709         federal-budget,state-budget,transportation           tom-petri
# 11990                             bipartisanship,history  charlotte-bergmann
# 12028                                       economy,jobs     hillary-clinton
# 12453  consumer-safety,government-regulation,public-s...    marsha-blackburn
#
#                                job_title         state party_affiliation  \
# 1858                        U.S. senator       Arizona        republican
# 2710                 Lieutenant governor         Texas        republican
# 3269                                 NaN           NaN        republican
# 4399           Candidate for U.S. Senate  Pennsylvania        republican
# 4852                      Ohio treasurer          Ohio        republican
# 4953              Senate minority leader      Kentucky        republican
# 6805        State Senator, 20th District     Wisconsin        republican
# 7676   U.S. House member -- 4th District     Wisconsin          democrat
# 8935                                 NaN          Utah        republican
# 9429                 U.S. representative  Pennsylvania        republican
# 9671                           President      Illinois          democrat
# 10363                 Mayor, San Antonio         Texas          democrat
# 10867              Governor of Louisiana     Louisiana        republican
# 11454                                NaN        Alaska        republican
# 11543                          President      Illinois          democrat
# 11629                           Governor         Texas        republican
# 11709  U.S. House member -- 6th District     Wisconsin        republican
# 11990                          Candidate     Tennessee        republican
# 12028             Presidential candidate      New York          democrat
# 12453                U.S. Representative     Tennessee        republican
#
#        barely_true_counts  false_counts  half_true_counts  ...  \
# 1858                 31.0          39.0              31.0  ...
# 2710                  8.0           8.0              10.0  ...
# 3269                  2.0           3.0               3.0  ...
# 4399                  3.0           2.0               2.0  ...
# 4852                  4.0           5.0               4.0  ...
# 4953                  7.0           6.0               5.0  ...
# 6805                  2.0           4.0               1.0  ...
# 7676                  3.0           4.0               4.0  ...
# 8935                  5.0           1.0               5.0  ...
# 9429                  1.0           1.0               1.0  ...
# 9671                 70.0          71.0             160.0  ...
# 10363                 0.0           0.0               3.0  ...
# 10867                 0.0           1.0               4.0  ...
# 11454                 9.0          19.0               9.0  ...
# 11543                70.0          71.0             160.0  ...
# 11629                30.0          30.0              42.0  ...
# 11709                 0.0           1.0               0.0  ...
# 11990                 0.0           2.0               0.0  ...
# 12028                40.0          29.0              69.0  ...
# 12453                 2.0           2.0               1.0  ...
#
#        justification_len  statement_wc justification_wc articles_wc bin_label  \
# 1858                 732            12              116         212     false
# 2710                 359             5               60         210     false
# 3269                 290             4               45         197     false
# 4399                 315             4               61         219     false
# 4852                 708            36              117         207      true
# 4953                 856             9              144         213     false
# 6805                 534             6               93         193     false
# 7676                 413            16               62         215      true
# 8935                 441             6               74         217      true
# 9429                 628             7              113         211      true
# 9671                 376             9               72         218     false
# 10363                130            11               21         185      true
# 10867                648             3              101         216     false
# 11454                470             4               85         215     false
# 11543                297             3               51         210      true
# 11629                205             6               36         218     false
# 11709                282             3               51         194     false
# 11990                390             7               68         211     false
# 12028                304             8               51         219      true
# 12453                480            22               79         218     false
#
#       label_score  punctuations  statement_word_count  \
# 1858           -2             7                    12
# 2710           -2             0                     5
# 3269           -2             3                     4
# 4399           -2             2                     4
# 4852            1             3                    36
# 4953           -2             0                     9
# 6805           -2             1                     6
# 7676            3             2                    16
# 8935            3             2                     6
# 9429            1             1                     7
# 9671           -2             0                     9
# 10363           3             2                    11
# 10867          -2             1                     3
# 11454          -2             3                     4
# 11543           1             1                     3
# 11629          -2             1                     6
# 11709          -2             2                     3
# 11990          -2             2                     7
# 12028           2             1                     8
# 12453          -2             0                    22
#
#       justification_word_count articles_word_count
# 1858                       116                 212
# 2710                        60                 210
# 3269                        45                 197
# 4399                        61                 219
# 4852                       117                 207
# 4953                       144                 213
# 6805                        93                 193
# 7676                        62                 215
# 8935                        74                 217
# 9429                       113                 211
# 9671                        72                 218
# 10363                       21                 185
# 10867                      101                 216
# 11454                       85                 215
# 11543                       51                 210
# 11629                       36                 218
# 11709                       51                 194
# 11990                       68                 211
# 12028                       51                 219
# 12453                       79                 218
#
# [20 rows x 35 columns]

# %%
df[df["statement"]=='On a cap-and-trade plan.']
# Out:
#        label                 statement  \
# 2885   false  On a cap-and-trade plan.
# 3269   false  On a cap-and-trade plan.
# 11454  false  On a cap-and-trade plan.
#
#                                                subject       speaker  \
# 2885                 cap-and-trade,climate-change,jobs   scott-bruun
# 3269          cap-and-trade,climate-change,environment  tim-pawlenty
# 11454  cap-and-trade,climate-change,energy,environment   sarah-palin
#
#                   job_title   state party_affiliation  barely_true_counts  \
# 2885   State representative  Oregon        republican                 2.0
# 3269                    NaN     NaN        republican                 2.0
# 11454                   NaN  Alaska        republican                 9.0
#
#        false_counts  half_true_counts  ...  justification_len  statement_wc  \
# 2885            1.0               0.0  ...                353             4
# 3269            3.0               3.0  ...                290             4
# 11454          19.0               9.0  ...                470             4
#
#       justification_wc articles_wc bin_label label_score  punctuations  \
# 2885                54         204     false          -2             3
# 3269                45         197     false          -2             3
# 11454               85         215     false          -2             3
#
#        statement_word_count justification_word_count articles_word_count
# 2885                      4                       54                 204
# 3269                      4                       45                 197
# 11454                     4                       85                 215
#
# [3 rows x 35 columns]

# %%
df[df["statement"]=='On the Trans-Pacific Partnership.']
# Out:
#       label                          statement subject          speaker  \
# 2937  false  On the Trans-Pacific Partnership.   trade  hillary-clinton
# 4399  false  On the Trans-Pacific Partnership.   trade       pat-toomey
#
#                       job_title         state party_affiliation  \
# 2937     Presidential candidate      New York          democrat
# 4399  Candidate for U.S. Senate  Pennsylvania        republican
#
#       barely_true_counts  false_counts  half_true_counts  ...  \
# 2937                40.0          29.0              69.0  ...
# 4399                 3.0           2.0               2.0  ...
#
#       justification_len  statement_wc justification_wc articles_wc bin_label  \
# 2937               1236             4              195         208     false
# 4399                315             4               61         219     false
#
#      label_score  punctuations  statement_word_count justification_word_count  \
# 2937          -2             2                     4                      195
# 4399          -2             2                     4                       61
#
#      articles_word_count
# 2937                 208
# 4399                 219
#
# [2 rows x 35 columns]

# %%
df[df["statement"]=='On high-speed rail.']
# Out:
#        label            statement  \
# 3494   false  On high-speed rail.
# 11709  false  On high-speed rail.
#
#                                                subject           speaker  \
# 3494   corrections-and-updates,stimulus,transportation  mike-haridopolos
# 11709       federal-budget,state-budget,transportation         tom-petri
#
#                                job_title      state party_affiliation  \
# 3494            Florida Senate President    Florida        republican
# 11709  U.S. House member -- 6th District  Wisconsin        republican
#
#        barely_true_counts  false_counts  half_true_counts  ...  \
# 3494                  0.0           3.0               1.0  ...
# 11709                 0.0           1.0               0.0  ...
#
#        justification_len  statement_wc justification_wc articles_wc bin_label  \
# 3494                 352             3               66         215     false
# 11709                282             3               51         194     false
#
#       label_score  punctuations  statement_word_count  \
# 3494           -2             2                     3
# 11709          -2             2                     3
#
#       justification_word_count articles_word_count
# 3494                        66                 215
# 11709                       51                 194
#
# [2 rows x 35 columns]

# %%
df[df.duplicated(subset=["statement"], keep=False) & (df["statement"]=='On high-speed rail.')]
# Out:
#        label            statement  \
# 3494   false  On high-speed rail.
# 11709  false  On high-speed rail.
#
#                                                subject           speaker  \
# 3494   corrections-and-updates,stimulus,transportation  mike-haridopolos
# 11709       federal-budget,state-budget,transportation         tom-petri
#
#                                job_title      state party_affiliation  \
# 3494            Florida Senate President    Florida        republican
# 11709  U.S. House member -- 6th District  Wisconsin        republican
#
#        barely_true_counts  false_counts  half_true_counts  ...  \
# 3494                  0.0           3.0               1.0  ...
# 11709                 0.0           1.0               0.0  ...
#
#        justification_len  statement_wc justification_wc articles_wc bin_label  \
# 3494                 352             3               66         215     false
# 11709                282             3               51         194     false
#
#       label_score  punctuations  statement_word_count  \
# 3494           -2             2                     3
# 11709          -2             2                     3
#
#       justification_word_count articles_word_count
# 3494                        66                 215
# 11709                       51                 194
#
# [2 rows x 35 columns]

# %% [markdown]
# ### Note
#
# There is no need to remove duplicates because there are no row duplicates and duplicates of statement and label differ in significant way.

# %% [markdown]
# # Univariate analysis

# %%
df["label"].value_counts()
# Out:
# label
# half-true      2638
# false          2511
# mostly-true    2466
# barely-true    2108
# true           2063
# pants-fire     1050
# Name: count, dtype: int64

# %%
custom_order = ["pants-fire", "false", "barely-true", "half-true", "mostly-true", "true"]
custom_order2way = ["false", "true"]

# %% [markdown]
# ### Zbalansowanie zbioru dla 6 klas decyzyjnych

# %%
ax = df["label"].value_counts() \
    .reindex(custom_order) \
    .plot(kind='barh')
ax.set_xlabel("Liczba przykładów")
ax.set_ylabel("Klasa decyzyjna")
plt.savefig("../imgs/balance_6way.png", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Zbalansowanie zbioru dla 2 klas decyzyjnych

# %%
ax = df["bin_label"].value_counts() \
    .reindex(custom_order2way) \
    .plot(kind='barh')
ax.set_xlabel("Liczba przykładów")
ax.set_ylabel("Klasa decyzyjna")
plt.savefig("../imgs/balance_2way.png", bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Vocabulary size analysis

# %%
nlp = spacy.load("en_core_web_sm")

stop_words = stop_words.STOP_WORDS

example_sentence = nlp("Annie doesn't have a cat")
for w in example_sentence:
    print(w)
# Out:
# Annie
# does
# n't
# have
# a
# cat

# %%
word_counts = Counter()

# Process the column using spaCy's nlp.pipe for efficiency
for doc in nlp.pipe(df['statement'].astype('unicode').values, batch_size=50):
    for token in doc:
        # You can adjust the filters as needed (e.g., filtering stop words)
        if not token.is_punct and not token.is_space:
            word_counts[token.text.lower()] += 1

# %%
print('STATEMENT VOCABULARY STATS:\n')
print(f'Vocabulary size: {len(word_counts.items())}')
print(f'Word repeats: {word_counts.total()}')
print(f'Most common words: {word_counts.most_common(20)}')
# Out:
# STATEMENT VOCABULARY STATS:
#
# Vocabulary size: 13969
# Word repeats: 235091
# Most common words: [('the', 12287), ('in', 6383), ('of', 6032), ('to', 5631), ('a', 4609), ('and', 3589), ('says', 2977), ('for', 2629), ('that', 2448), ('is', 2282), ('on', 1873), ('has', 1639), ('$', 1618), ('have', 1591), ('percent', 1504), ('are', 1413), ('than', 1402), ('we', 1316), ('more', 1196), ('was', 1191)]

# %%
word_counts_justification = Counter()

# Process the column using spaCy's nlp.pipe for efficiency
for doc in nlp.pipe(df['justification'].astype('unicode').values, batch_size=50):
    for token in doc:
        # You can adjust the filters as needed (e.g., filtering stop words)
        if not token.is_punct and not token.is_space:
            word_counts_justification[token.text.lower()] += 1

# %%
print('JUSTIFICATION VOCABULARY STATS:\n')
print(f'Vocabulary size: {len(word_counts_justification.items())}')
print(f'Word repeats: {word_counts_justification.total()}')
print(f'Most common words: {word_counts_justification.most_common(20)}')
# Out:
# JUSTIFICATION VOCABULARY STATS:
#
# Vocabulary size: 26993
# Word repeats: 929228
# Most common words: [('the', 55372), ('to', 22423), ('of', 21719), ('that', 19983), ('a', 19182), ('in', 19141), ('and', 16678), ('is', 10763), ('for', 9681), ('but', 7941), ('said', 7931), ('on', 7527), ('it', 7242), ('he', 6382), ('not', 6262), ('was', 6029), ('as', 5472), ('have', 4869), ('we', 4651), ('has', 4638)]

# %%
common_word_counts = word_counts + word_counts_justification

# zrobić nową zmienną, usunąć stop_words i wypisać najpopularniejsze słowa bez stop_words

# %%
print('COMMON VOCABULARY STATS:\n')
print(f'Vocabulary size: {len(common_word_counts.items())}')
print(f'Word repeats: {common_word_counts.total()}')
print(f'Most common words: {common_word_counts.most_common(20)}')
# Out:
# COMMON VOCABULARY STATS:
#
# Vocabulary size: 28962
# Word repeats: 1164319
# Most common words: [('the', 67659), ('to', 28054), ('of', 27751), ('in', 25524), ('a', 23791), ('that', 22431), ('and', 20267), ('is', 13045), ('for', 12310), ('on', 9400), ('said', 8395), ('it', 8253), ('but', 8248), ('was', 7220), ('he', 7206), ('not', 7141), ('have', 6460), ('as', 6370), ('has', 6277), ('are', 6029)]

# %%
common_words_counts_without_stop_words = Counter()

for k, v in common_word_counts.items():
    if k not in stop_words:
        common_words_counts_without_stop_words[k] = v

# %%
print('COMMON VOCABULARY STATS WITHOUT STOPWORDS:\n')
print(f'Vocabulary size: {len(common_words_counts_without_stop_words.items())}')
print(f'Word repeats: {common_words_counts_without_stop_words.total()}')
print(f'Most common words: {common_words_counts_without_stop_words.most_common(10)}')
# Out:
# COMMON VOCABULARY STATS WITHOUT STOPWORDS:
#
# Vocabulary size: 28667
# Word repeats: 617537
# Most common words: [('said', 8395), ('percent', 4703), ('$', 4537), ('says', 4135), ('state', 3945), ('nt', 3567), ('obama', 3332), ('tax', 3105), ('years', 2697), ('year', 2649)]

# %% [markdown]
# ## Links analysis

# %%
common_word_counts["http"]
# Out:
# 0

# %%
common_word_counts["https"]
# Out:
# 0

# %%
common_word_counts["www"]
# Out:
# 8

# %%
df[df["statement"].str.contains("www")]
# Out:
# Empty DataFrame
# Columns: [label, statement, subject, speaker, job_title, state, party_affiliation, barely_true_counts, false_counts, half_true_counts, mostly_true_counts, pants_on_fire_counts, context, justification, sentiment, question, grammar_errors, ratio_of_capital_letters, curse, emotion, gibberish, offensiveness, political_bias, articles, statement_len, justification_len, statement_wc, justification_wc, articles_wc, bin_label, label_score, punctuations, statement_word_count, justification_word_count, articles_word_count]
# Index: []
#
# [0 rows x 35 columns]

# %%
df[df["justification"].str.contains("www")]
# Out:
#             label                                          statement  \
# 702    pants-fire  Says Texas voters are being asked to act this ...
# 2757   pants-fire  The Democrats are very sly. (in New Hampshire)...
# 7664    half-true  Says that Mitt Romneys response to the crisis ...
# 10750   half-true  Fifty-seven of Rubios 100 ideas ultimately bec...
# 11757        true  When the national debt reaches $15 trillion, i...
# 12663        true  MikeHuckabee.com gets "more hits than virtuall...
#
#                             subject            speaker  \
# 702                 elections,taxes        chain-email
# 2757               elections,states       chris-sununu
# 7664                bankruptcy,jobs  jennifer-granholm
# 10750  candidates-biography,florida        marco-rubio
# 11757        deficit,federal-budget      leonard-lance
# 12663                     elections      mike-huckabee
#
#                          job_title          state party_affiliation  \
# 702                            NaN            NaN              none
# 2757           Executive Councilor  New Hampshire        republican
# 7664   Former governor of Michigan       Michigan          democrat
# 10750                 U.S. Senator        Florida        republican
# 11757                          NaN            NaN        republican
# 12663                       author       Arkansas        republican
#
#        barely_true_counts  false_counts  half_true_counts  ...  \
# 702                  11.0          43.0               8.0  ...
# 2757                  0.0           1.0               1.0  ...
# 7664                  1.0           0.0               3.0  ...
# 10750                33.0          24.0              32.0  ...
# 11757                 0.0           0.0               1.0  ...
# 12663                12.0           5.0               9.0  ...
#
#        justification_len  statement_wc justification_wc articles_wc bin_label  \
# 702                  493            18               87         222     false
# 2757                 414            33               63         181     false
# 7664                 612            17               99         215      true
# 10750               9320             8             1834         218      true
# 11757                546            28               87         202      true
# 12663                505            10               85         200      true
#
#       label_score  punctuations  statement_word_count  \
# 702            -3             0                    18
# 2757           -3             4                    33
# 7664            1             2                    17
# 10750           1             2                     8
# 11757           3             7                    28
# 12663           3             4                    10
#
#       justification_word_count articles_word_count
# 702                         87                 222
# 2757                        63                 181
# 7664                        99                 215
# 10750                     1834                 218
# 11757                       87                 202
# 12663                       85                 200
#
# [6 rows x 35 columns]

# %%
[x[x.index("www.")-30:x.index("www.")+50] for x in list(df[df["justification"].str.contains("www")]['justification'])]
# Out:
# ['recommends an online visit to www. votexas. org or a telephone call to the secre',
#  "ce. But Richardson's web site www. getourtroopsout. com states that Richardson w",
#  'the country. "His web site -- www. getourtroopsout. com  emphasizes withdrawal i',
#  'lth insurance. State launched www. floridahealthfinder. gov in late 2007. 90    ',
#  'ere based on a website called www. usdebtclock. org. Those numbers back Lances s',
#  'little more attention. "While www. mikehuckabee. com might never share the same ']

# %%
df[df["justification"].str.contains("\.com")]['justification']
# Out:
# Series([], Name: justification, dtype: object)

# %%
df[df["statement"].str.contains("http")]
# Out:
# Empty DataFrame
# Columns: [label, statement, subject, speaker, job_title, state, party_affiliation, barely_true_counts, false_counts, half_true_counts, mostly_true_counts, pants_on_fire_counts, context, justification, sentiment, question, grammar_errors, ratio_of_capital_letters, curse, emotion, gibberish, offensiveness, political_bias, articles, statement_len, justification_len, statement_wc, justification_wc, articles_wc, bin_label, label_score, punctuations, statement_word_count, justification_word_count, articles_word_count]
# Index: []
#
# [0 rows x 35 columns]

# %%
df[df["justification"].str.contains("http")]
# Out:
# Empty DataFrame
# Columns: [label, statement, subject, speaker, job_title, state, party_affiliation, barely_true_counts, false_counts, half_true_counts, mostly_true_counts, pants_on_fire_counts, context, justification, sentiment, question, grammar_errors, ratio_of_capital_letters, curse, emotion, gibberish, offensiveness, political_bias, articles, statement_len, justification_len, statement_wc, justification_wc, articles_wc, bin_label, label_score, punctuations, statement_word_count, justification_word_count, articles_word_count]
# Index: []
#
# [0 rows x 35 columns]

# %% [markdown]
# ## State analysis

# %% [markdown]
# ### Unique state vocabulary count

# %%
df["state"].astype(str).apply(lambda x: x.strip().lower()).unique().shape
# Out:
# (69,)

# %%
df["state"].astype(str).apply(lambda x: x.strip().lower()).unique()
# Out:
# array(['texas', 'virginia', 'illinois', 'nan', 'florida', 'wisconsin',
#        'new jersey', 'vermont', 'massachusetts', 'maryland',
#        'washington, d.c.', 'oregon', 'new york', 'california', 'missouri',
#        'rhode island', 'west virginia', 'arkansas', 'new hampshire',
#        'ohio', 'georgia', 'arizona', 'wyoming', 'delaware', 'kentucky',
#        'kansas', 'colorado', 'north carolina', 'new mexico', 'alaska',
#        'south carolina', 'minnesota', 'tennessee', 'pennsylvania', 'iowa',
#        'connecticut', 'louisiana', 'indiana', 'utah', 'michigan',
#        'oklahoma', 'nevada', 'virgina', 'nebraska', 'washington d.c.',
#        'alabama', 'russia', 'washington state', 'washington',
#        'district of columbia', 'unknown', 'mississippi', 'china',
#        'united kingdom', 'south dakota', 'qatar', 'montana',
#        'north dakota', 'idaho', 'maine',
#        'virginia director, coalition to stop gun violence', 'virgiia',
#        'hawaii', 'atlanta', 'tennesse', 'washington dc',
#        'pa - pennsylvania', 'tex', 'the united states'], dtype=object)

# %%
df["state"].value_counts()
# Out:
# state
# Texas             1263
# Florida           1235
# Wisconsin          904
# New York           832
# Illinois           698
#                   ...
# Virginia             1
# United Kingdom       1
# China                1
# Rhode island         1
# Georgia              1
# Name: count, Length: 84, dtype: int64

# %% [markdown]
# ### Liczba wypowiedzi w 10 najpopularniejszych stanach

# %%
ax = df["state"].value_counts() \
    .head(10) \
    .plot(kind='barh')
ax.set_ylabel("Stan")
ax.set_xlabel("Liczba przykładów")

plt.savefig("../imgs/state_balance.png", bbox_inches='tight')
plt.show()

# %%
df["speaker"].value_counts().head(10)
# Out:
# speaker
# barack-obama       616
# donald-trump       344
# hillary-clinton    297
# mitt-romney        216
# john-mccain        189
# scott-walker       184
# chain-email        178
# rick-perry         173
# marco-rubio        153
# rick-scott         150
# Name: count, dtype: int64

# %%
d = {' '.join([x.capitalize() for x in k.split('-')]): v for k, v in df["speaker"].value_counts().head(10).to_dict().items()}
d
# Out:
# {'Barack Obama': 616,
#  'Donald Trump': 344,
#  'Hillary Clinton': 297,
#  'Mitt Romney': 216,
#  'John Mccain': 189,
#  'Scott Walker': 184,
#  'Chain Email': 178,
#  'Rick Perry': 173,
#  'Marco Rubio': 153,
#  'Rick Scott': 150}

# %%
pd.Series(d).to_csv("csv/most_popular_speakers.csv", index_label='speaker', header=['count'])

# %% [markdown]
# ### 10 najpopularniejszych mówców

# %%
ax = df["speaker"].value_counts() \
    .head(10) \
    .plot(kind='barh')
ax.set_xlabel("Liczba przykładów")
ax.set_ylabel("Kolumna speaker")

plt.savefig("../imgs/most_popular_speakers.png", bbox_inches='tight')
plt.show()

# %%
subjects = []
for _, row in tqdm(df.iterrows(), total=df.shape[0]):
    subjects += str(row["subject"]).split(",")
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████| 12836/12836 [00:00<00:00, 31823.51it/s]

# %%
subjects = pd.DataFrame.from_dict({"subjects": subjects})
subjects["subjects"] = subjects["subjects"].apply(lambda s: s[0] if isinstance(s, tuple) else s)

# %%
subjects.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27796 entries, 0 to 27795
# Data columns (total 1 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   subjects  27796 non-null  object
# dtypes: object(1)
# memory usage: 217.3+ KB

# %%
subjects.describe()
# Out:
#        subjects
# count     27796
# unique      144
# top     economy
# freq       1435

# %%
subjects.value_counts() \
    .head(10)
# Out:
# subjects
# economy                 1435
# health-care             1434
# taxes                   1221
# federal-budget           943
# education                930
# jobs                     902
# state-budget             884
# candidates-biography     808
# elections                759
# immigration              645
# Name: count, dtype: int64

# %% [markdown]
# ### 10 najpopularniejszych tematów

# %%
ax = subjects["subjects"].value_counts() \
    .head(10) \
    .plot(kind='barh')
ax.set_xlabel("Liczba przykładów")
ax.set_ylabel("Temat")

plt.savefig("../imgs/top_topics.png", bbox_inches='tight')
plt.show()

# %%
print(subjects[:5])
# Out:
#               subjects
# 0             abortion
# 1               energy
# 2              history
# 3  job-accomplishments
# 4       foreign-policy

# %% [markdown]
# ### Pants-on-fire speaker counts

# %%
ax = df["pants_on_fire_counts"].plot(kind="hist")
ax.set_xlabel("Pants-on-fire counts")
# Out:
# Text(0.5, 0, 'Pants-on-fire counts')

# %% [markdown]
# ### False speaker counts

# %%
ax = df["false_counts"].plot(kind="hist")
ax.set_xlabel("False counts")
# Out:
# Text(0.5, 0, 'False counts')

# %% [markdown]
# ### Barely-true speaker counts

# %%
ax = df["barely_true_counts"].plot(kind="hist")
ax.set_xlabel("Barely-true counts")
# Out:
# Text(0.5, 0, 'Barely-true counts')

# %% [markdown]
# ### Half-true speaker counts

# %%
ax = df["half_true_counts"].plot(kind="hist")
ax.set_xlabel("Half-true counts")
# Out:
# Text(0.5, 0, 'Half-true counts')

# %% [markdown]
# ### Mostly-true speaker counts

# %%
ax = df["mostly_true_counts"].plot(kind="hist")
ax.set_xlabel("Mostly-true counts")
# Out:
# Text(0.5, 0, 'Mostly-true counts')

# %% [markdown]
# ## Check if there are any non float values in speaker counts

# %%
df[df["pants_on_fire_counts"].apply(lambda x: pd.isna(x) or x!=int(x))].dropna().shape[0]
# Out:
# 0

# %%
df[df["false_counts"].apply(lambda x: pd.isna(x) or x!=int(x))].dropna().shape[0]
# Out:
# 0

# %%
df[df["barely_true_counts"].apply(lambda x: pd.isna(x) or x!=int(x))].dropna().shape[0]
# Out:
# 0

# %%
df[df["mostly_true_counts"].apply(lambda x: pd.isna(x) or x!=int(x))].dropna().shape[0]
# Out:
# 0

# %%
df[df["half_true_counts"].apply(lambda x: pd.isna(x) or x!=int(x))].dropna().shape[0]
# Out:
# 0

# %% [markdown]
# ## Check distribution of questions

# %%
df["question"].value_counts()
# Out:
# question
# not_question    12673
# question          163
# Name: count, dtype: int64

# %% [markdown]
# ### Typy zdań w zbiorze

# %%
ax = df["question"].value_counts() \
    .plot(kind='barh')
ax.set_xlabel("Liczba przykładów")
ax.set_ylabel("Kolumna question")

plt.savefig("../imgs/sentences_types.png", bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Label balance in question vs not_question subsets

# %% [markdown]
# ### 6-way classification in question subset

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 5), sharey=False)

df[df["question"] == 'question']["label"].value_counts() \
    .reindex(custom_order) \
    .plot(kind='barh', ax=axs[0], title="Zbalansowanie zbioru w podzbiorze question\ndla 6 klas decyzyjnych")
axs[0].set_xlabel("Liczba przykładów")
axs[0].set_ylabel("Klasa decyzyjna")

df["label"].value_counts() \
    .reindex(custom_order) \
    .plot(kind='barh', ax=axs[1], title="Zbalansowanie zbioru dla 6 klas decyzyjnych")
axs[1].set_xlabel("Liczba przykładów")
axs[1].set_ylabel("Klasa decyzyjna")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 6-way classification in not_question subset

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 5), sharey=False)

df[df["question"] == 'not_question']["label"].value_counts() \
    .reindex(custom_order) \
    .plot(kind='barh', ax=axs[0], title="Zbalansowanie zbioru w podzbiorze not_question\ndla 6 klas decyzyjnych")
axs[0].set_xlabel("Liczba przykładów")
axs[0].set_ylabel("Klasa decyzyjna")

df["label"].value_counts() \
    .reindex(custom_order) \
    .plot(kind='barh', ax=axs[1], title="Zbalansowanie zbioru dla 6 klas decyzyjnych")
axs[1].set_xlabel("Liczba przykładów")
axs[1].set_ylabel("Klasa decyzyjna")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Both

# %%
# Oblicz value_counts jako procenty
vc_question = df[df["question"] == 'question']["label"].value_counts(normalize=True).reindex(custom_order, fill_value=0) * 100
vc_all = df["label"].value_counts(normalize=True).reindex(custom_order, fill_value=0) * 100

# Pozycje słupków na osi Y
y = np.arange(len(custom_order))
height = 0.35  # wysokość pojedynczego słupka

# Rysowanie
fig, axs = plt.subplots(1, 2, figsize=(12, 5), sharey=False)

axs[0].barh(y - height/2, vc_question.values, height=height, label="Podzbiór question")
axs[0].barh(y + height/2, vc_all.values, height=height, label="Cały zbiór")

# Opisy osi
axs[0].set_yticks(y)
axs[0].set_yticklabels(custom_order)
axs[0].set_xlabel("Procent przykładów")
axs[0].set_ylabel("Klasa decyzyjna")
axs[0].set_title("Znormalizowany rozkład klas:\npodzbiór question vs cały zbiór")
axs[0].legend()
axs[0].grid(True, axis='x', linestyle='--', alpha=0.5)

vc_question2 = df[df["question"] == 'not_question']["label"].value_counts(normalize=True).reindex(custom_order, fill_value=0) * 100
vc_all2 = df["label"].value_counts(normalize=True).reindex(custom_order, fill_value=0) * 100

# Pozycje słupków na osi Y
y2 = np.arange(len(custom_order))
height2 = 0.35  # wysokość pojedynczego słupka

axs[1].barh(y2 - height2/2, vc_question2.values, height=height2, label="Podzbiór not_question")
axs[1].barh(y2 + height2/2, vc_all2.values, height=height2, label="Cały zbiór")

# Opisy osi
axs[1].set_yticks(y2)
axs[1].set_yticklabels(custom_order)
axs[1].set_xlabel("Procent przykładów")
axs[1].set_ylabel("Klasa decyzyjna")
axs[1].set_title("Znormalizowany rozkład klas:\npodzbiór not_question vs cały zbiór")
axs[1].legend()
axs[1].grid(True, axis='x', linestyle='--', alpha=0.5)

# Dodanie wartości procentowych na końcu słupków w axs[0]
for i, (v1, v2) in enumerate(zip(vc_question.values, vc_all.values)):
    axs[0].text(v1 / 2, i - height/2, f"{v1:.3f}%", va='center', ha='center', color='white', fontsize=8)
    axs[0].text(v2 / 2, i + height/2, f"{v2:.3f}%", va='center', ha='center', color='white', fontsize=8)

# Dodanie wartości procentowych na końcu słupków w axs[1]
for i, (v1, v2) in enumerate(zip(vc_question2.values, vc_all2.values)):
    axs[1].text(v1 / 2, i - height2/2, f"{v1:.3f}%", va='center', ha='center', color='white', fontsize=8)
    axs[1].text(v2 / 2, i + height2/2, f"{v2:.3f}%", va='center', ha='center', color='white', fontsize=8)

plt.tight_layout()
plt.savefig("../imgs/questions_balance_per_subsets.png", bbox_inches='tight')
plt.show()

# %%
# Oblicz value_counts jako procenty
vc_question = df[df["question"] == 'question']["bin_label"].value_counts(normalize=True).reindex(custom_order2way, fill_value=0) * 100
vc_all = df["bin_label"].value_counts(normalize=True).reindex(custom_order2way, fill_value=0) * 100

# Pozycje słupków na osi Y
y = np.arange(len(custom_order2way))
height = 0.35  # wysokość pojedynczego słupka

# Rysowanie
fig, axs = plt.subplots(1, 2, figsize=(12, 5), sharey=False)

axs[0].barh(y - height/2, vc_question.values, height=height, label="Podzbiór question")
axs[0].barh(y + height/2, vc_all.values, height=height, label="Cały zbiór")

# Opisy osi
axs[0].set_yticks(y)
axs[0].set_yticklabels(custom_order2way)
axs[0].set_xlabel("Procent przykładów")
axs[0].set_ylabel("Klasa decyzyjna")
axs[0].set_title("Znormalizowany rozkład klas:\npodzbiór question vs cały zbiór")
axs[0].legend()
axs[0].grid(True, axis='x', linestyle='--', alpha=0.5)

vc_question2 = df[df["question"] == 'not_question']["bin_label"].value_counts(normalize=True).reindex(custom_order2way, fill_value=0) * 100
vc_all2 = df["bin_label"].value_counts(normalize=True).reindex(custom_order2way, fill_value=0) * 100

# Pozycje słupków na osi Y
y2 = np.arange(len(custom_order2way))
height2 = 0.35  # wysokość pojedynczego słupka

axs[1].barh(y2 - height2/2, vc_question2.values, height=height2, label="Podzbiór not_question")
axs[1].barh(y2 + height2/2, vc_all2.values, height=height2, label="Cały zbiór")

# Opisy osi
axs[1].set_yticks(y2)
axs[1].set_yticklabels(custom_order2way)
axs[1].set_xlabel("Procent przykładów")
axs[1].set_ylabel("Klasa decyzyjna")
axs[1].set_title("Znormalizowany rozkład klas:\npodzbiór not_question vs cały zbiór")
axs[1].legend()
axs[1].grid(True, axis='x', linestyle='--', alpha=0.5)

# Dodanie wartości procentowych na końcu słupków w axs[0]
for i, (v1, v2) in enumerate(zip(vc_question.values, vc_all.values)):
    axs[0].text(v1 / 2, i - height/2, f"{v1:.3f}%", va='center', ha='center', color='white', fontsize=12)
    axs[0].text(v2 / 2, i + height/2, f"{v2:.3f}%", va='center', ha='center', color='white', fontsize=12)

# Dodanie wartości procentowych na końcu słupków w axs[1]
for i, (v1, v2) in enumerate(zip(vc_question2.values, vc_all2.values)):
    axs[1].text(v1 / 2, i - height2/2, f"{v1:.3f}%", va='center', ha='center', color='white', fontsize=12)
    axs[1].text(v2 / 2, i + height2/2, f"{v2:.3f}%", va='center', ha='center', color='white', fontsize=12)

plt.tight_layout()
plt.savefig("../imgs/questions_balance_per_subsets_2way.png", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### 2-way classification in question subset

# %%
df[df["question"] == 'question']["bin_label"].value_counts()
# Out:
# bin_label
# true     87
# false    76
# Name: count, dtype: int64

# %% [markdown]
# ### Zbalansowanie zbioru dla klasyfikacji 2-klasowej, gdy kolumna question = question

# %%
ax = df[df["question"] == 'question']["bin_label"].value_counts() \
    .plot(kind='barh', title="")

# %% [markdown]
# ### Zbalansowanie zbioru dla klasyfikacji 2-klasowej, gdy kolumna question = not_question

# %%
df[df["question"] == 'not_question']["bin_label"].value_counts() \
    .plot(kind='barh')
# Out:
# <Axes: ylabel='bin_label'>

# %% [markdown]
# ## Sentiment distribution

# %% [markdown]
# ### Rozkład sentymentu w zbiorze

# %%
ax = df['sentiment'].value_counts() \
    .plot(kind='barh')
ax.set_xlabel("Liczba przykładów")
ax.set_ylabel("Kolumna sentiment")

plt.savefig("../imgs/sentiment_distibution.png", bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Check average text length per label class

# %%
df.groupby("label")["statement_len"].mean()
# Out:
# label
# barely-true    108.292220
# false           99.868180
# half-true      111.619788
# mostly-true    107.950122
# pants-fire     102.964762
# true           104.931168
# Name: statement_len, dtype: float64

# %% [markdown]
# ### Zagregowana średnia liczba słów w statement na klasę

# %%
ax = df.groupby("label")["statement_wc"].mean() \
    .reindex(custom_order) \
    .plot(kind='barh')
ax.set_xlabel("average statement word count")
ax.set_ylabel("label")
# Out:
# Text(0, 0.5, 'label')

# %% [markdown]
# ### Zagregowana średnia liczba słów w statement na label 2-klasowy

# %%
ax = df.groupby("bin_label")["statement_wc"].mean() \
    .plot(kind='barh')
ax.set_xlabel("average statement word count")
ax.set_ylabel("bin_label")
# Out:
# Text(0, 0.5, 'bin_label')

# %% [markdown]
# ### Zagregowana średnia liczba słów w justification na klasę

# %%
ax = df.groupby("label")["justification_wc"].mean() \
    .reindex(custom_order) \
    .plot(kind='barh')
ax.set_xlabel("average justification word count")
ax.set_ylabel("label")
# Out:
# Text(0, 0.5, 'label')

# %% [markdown]
# ### Zagregowana średnia liczba słów w justification na label 2-klasowy

# %%
ax = df.groupby("bin_label")["justification_wc"].mean() \
    .plot(kind='barh')
ax.set_xlabel("average justification word count")
ax.set_ylabel("bin_label")
# Out:
# Text(0, 0.5, 'bin_label')

# %% [markdown]
# ### Verify on small subset

# %%
o = df[df["label"] == "false"].sample(5)[["justification", "justification_wc"]]
o
# Out:
#                                           justification  justification_wc
# 633   He said Rhode Island has the most liberal "goo...                14
# 7014  The mayors statistic isnt far off. According t...                86
# 7248  Neither time span offered in Hoekstras website...               124
# 4596  An image shared by The Other 98 Percent said "...               163
# 4193  "What I took from it was that you clean up you...                61

# %%
o["justification_wc"].mean()
# Out:
# 89.6

# %% [markdown]
# ### Zagregowana średnia liczba błędów gramatycznych na label 6-klasowy

# %%
ax = df.groupby("label")["grammar_errors"].mean() \
    .reindex(custom_order) \
    .plot(kind='barh')
ax.set_ylabel("6-way label")
ax.set_xlabel("average grammar errors")
# Out:
# Text(0.5, 0, 'average grammar errors')

# %% [markdown]
# ### Zagregowana średnia liczba błędów gramatycznych na label 2-klasowy

# %%
ax = df.groupby("bin_label")["grammar_errors"].mean() \
    .reindex(["false", "true"]) \
    .plot(kind='barh')
ax.set_ylabel("2-way label")
ax.set_xlabel("average grammar errors")
# Out:
# Text(0.5, 0, 'average grammar errors')

# %% [markdown]
# ## State vs political affiliation counts

# %%
n = 10

# Count total messages per state and get the top n
state_counts_total = df["state"].value_counts().nlargest(n)
top_states = state_counts_total.index  # Get state names

# Filter dataset to only include top n states
filtered_df = df[df["state"].isin(top_states)]

# Count occurrences per state and party
state_counts = filtered_df.groupby(["state", "party_affiliation"]).size().reset_index(name="count")

# Enforce state order based on total count
state_counts["state"] = pd.Categorical(state_counts["state"], categories=top_states, ordered=True)

# Plot
plt.figure(figsize=(10, 5))
sns.barplot(data=state_counts, x="state", y="count", hue="party_affiliation", palette="tab10", order=top_states)

# Formatting
plt.xlabel("Stan")
plt.ylabel("Liczba przykładów")
#plt.title(f"Liczba wypowiedzi na stan na przynależność partyjną ({n} najpopularniejszych stanów)")
plt.legend(title="Przynależność partyjna", bbox_to_anchor=(1.05, 1), loc="upper left")  # Move legend outside
plt.xticks(rotation=45)
plt.grid(axis="y", linestyle="--", alpha=0.7)

plt.savefig("../imgs/statements_vs_state_vs_party_affiliation.png", bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Party affiliation counts

# %%
df['party_affiliation'].unique().shape
# Out:
# (24,)

# %%
df['party_affiliation'].value_counts()
# Out:
# party_affiliation
# republican                      5687
# democrat                        4150
# none                            2185
# organization                     265
# independent                      182
# newsmaker                         66
# libertarian                       51
# journalist                        49
# activist                          47
# columnist                         45
# talk-show-host                    32
# state-official                    24
# labor-leader                      15
# business-leader                   11
# tea-party-member                  10
# education-official                 3
# green                              3
# constitution-party                 3
# government-body                    2
# county-commissioner                2
# liberal-party-canada               1
# Moderate                           1
# democratic-farmer-labor            1
# ocean-state-tea-party-action       1
# Name: count, dtype: int64

# %% [markdown]
# ### Przynależność partyjna w zbiorze (10 najpopularniejszych)

# %%
ax = df['party_affiliation'].value_counts() \
    .head(10) \
    .plot(kind='barh')
ax.set_xlabel("Liczba przykładów")
ax.set_ylabel("Kolumna party_affiliation")

plt.savefig("../imgs/party_affiliation.png", bbox_inches='tight')
plt.show()
# zastanowić się czy nie dać skali logarytmicznej

# %% [markdown]
# ## Unique context vocabulary count

# %%
words_in_context_counter = Counter()

for doc in nlp.pipe(df['context'].astype('unicode').values, batch_size=50):
    for token in doc:
        # You can adjust the filters as needed (e.g., filtering stop words)
        if not token.is_punct and not token.is_space:
            words_in_context_counter[token.text.lower()] += 1

# %%
list(words_in_context_counter.keys())[:10]
# Out:
# ['a',
#  'mailer',
#  'floor',
#  'speech',
#  'denver',
#  'news',
#  'release',
#  'an',
#  'interview',
#  'on']

# %%
len(words_in_context_counter.keys())
# Out:
# 2550

# %% [markdown]
# ## Job title analysis

# %%
df['job_title'].unique().shape
# Out:
# (1360,)

# %% [markdown]
# ### Job title vocabulary size

# %%
words_in_job_title_counter = Counter()

for doc in nlp.pipe(df['job_title'].astype('unicode').values, batch_size=50):
    for token in doc:
        # You can adjust the filters as needed (e.g., filtering stop words)
        if not token.is_punct and not token.is_space:
            words_in_job_title_counter[token.text.lower()] += 1

# %%
list(words_in_job_title_counter.keys())[:10]
# Out:
# ['state',
#  'representative',
#  'delegate',
#  'president',
#  'nan',
#  'wisconsin',
#  'assembly',
#  'speaker',
#  'u.s.',
#  'senator']

# %%
len(words_in_job_title_counter.keys())
# Out:
# 1290

# %% [markdown]
# # Feature Relationships

# %% [markdown]
# ### Label Score vs Grammar Errors (barwa = częstość)

# %%
# Compute frequency of each grammar_errors value
df["error_count"] = df.groupby(["label", "grammar_errors"])["grammar_errors"].transform("count")

# Create scatter plot with hue as frequency count
ax = sns.scatterplot(
    x=pd.Categorical(df["label"], categories=custom_order, ordered=True),
    y="grammar_errors",
    hue="error_count",  # Hue based on frequency
    size="error_count",  # Optional: Make points bigger for frequent values
    palette="viridis",  # Change color map to highlight differences
    data=df
)

ax.legend(title="Count of Occurrences")

df.drop("error_count", axis=1, inplace=True)

# %%
df[df['grammar_errors']==7]
# Out:
#             label                                          statement subject  \
# 4047  barely-true  Mike Madigan made a fortune on tax appeals Sav...   taxes
#
#                                                 speaker job_title      state  \
# 4047  citizens-michael-mcauliffe-and-house-republica...       NaN  Illinois
#
#      party_affiliation  barely_true_counts  false_counts  half_true_counts  \
# 4047        republican                 1.0           0.0               0.0
#
#       ...  justification_len  statement_wc justification_wc articles_wc  \
# 4047  ...                339            57               53         204
#
#      bin_label label_score  punctuations  statement_word_count  \
# 4047     false          -1             3                    57
#
#      justification_word_count articles_word_count
# 4047                       53                 204
#
# [1 rows x 35 columns]

# %%
df.groupby(['label', 'grammar_errors'])["grammar_errors"].count()
# Out:
# label        grammar_errors
# barely-true  0                 1440
#              1                  494
#              2                  138
#              3                   25
#              4                    8
#              5                    2
#              7                    1
# false        0                 1772
#              1                  572
#              2                  138
#              3                   24
#              4                    5
# half-true    0                 1864
#              1                  600
#              2                  139
#              3                   25
#              4                    8
#              5                    2
# mostly-true  0                 1784
#              1                  525
#              2                  127
#              3                   26
#              4                    2
#              5                    2
# pants-fire   0                  649
#              1                  311
#              2                   78
#              3                    9
#              4                    2
#              5                    1
# true         0                 1527
#              1                  420
#              2                   89
#              3                   20
#              4                    7
# Name: grammar_errors, dtype: int64

# %% [markdown]
# #### Ciąg dalszy...

# %%
grouped = df.groupby("label", observed=True)["grammar_errors"]
means = grouped.mean().reindex(custom_order)
stds = grouped.std().reindex(custom_order)  # Standard deviation (for error bars)
medians = grouped.median().reindex(custom_order)

labels = means.index
y = np.arange(len(labels))
x = means.values
xerr = stds.values

fig, axs = plt.subplots(1, 2, figsize=(12, 5), sharey=False)

axs[0].errorbar(x, y, xerr=[xerr, xerr], fmt='s', capsize=4, color='coral', label='średnia ± std')

# Dodaj mediany
axs[0].scatter(medians.values, y, color='blue', label='mediana', zorder=3)

axs[0].set_yticks(y, labels)
axs[0].set_yticklabels(labels)
axs[0].set_xlabel("Średnia liczba błędów gramatycznych")
axs[0].set_ylabel("Klasa decyzyjna")
axs[0].set_title("Błędy gramatyczne na klasę decyzyjną\n(6 klas, średnia ± odchylenie standardowe, mediana)")
axs[0].legend()
axs[0].grid(True, axis='x', linestyle='--', alpha=0.5)

df["label"].value_counts() \
    .reindex(custom_order) \
    .plot(kind='barh', ax=axs[1], title="Zbalansowanie zbioru dla 6 klas decyzyjnych")
axs[1].set_xlabel("Liczba przykładów")
axs[1].set_ylabel("Klasa decyzyjna")

plt.tight_layout()

plt.savefig("../imgs/grammar_errors_vs_label_6way.png", bbox_inches='tight')
plt.show()

# %%
means
# Out:
# label
# pants-fire     0.482857
# false          0.374353
# barely-true    0.424099
# half-true      0.377180
# mostly-true    0.354826
# true           0.332525
# Name: grammar_errors, dtype: float64

# %%
grouped = df.groupby("bin_label", observed=True)["grammar_errors"]
means = grouped.mean()
stds = grouped.std()  # Standard deviation (for error bars)
medians = grouped.median()

labels = means.index
y = np.arange(len(labels))
x = means.values
xerr = stds.values

fig, axs = plt.subplots(1, 2, figsize=(12, 5), sharey=False)

axs[0].errorbar(x, y, xerr=[xerr, xerr], fmt='s', capsize=4, color='coral', label='średnia ± std')

# Dodaj mediany
axs[0].scatter(medians.values, y, color='blue', label='mediana', zorder=3)

axs[0].set_yticks(y, labels)
axs[0].set_yticklabels(labels)
axs[0].set_xlabel("Średnia liczba błędów gramatycznych")
axs[0].set_ylabel("Klasa decyzyjna")
axs[0].set_title("Błędy gramatyczne na klasę decyzyjną\n(2 klasy, średnia ± odchylenie standardowe, mediana)")
axs[0].legend()
axs[0].grid(True, axis='x', linestyle='--', alpha=0.5)

df["bin_label"].value_counts() \
    .reindex(custom_order2way) \
    .plot(kind='barh', ax=axs[1], title="Zbalansowanie zbioru dla 2 klas decyzyjnych")
axs[1].set_xlabel("Liczba przykładów")
axs[1].set_ylabel("Klasa decyzyjna")

plt.tight_layout()
plt.savefig("../imgs/grammar_errors_vs_label_2way.png", bbox_inches='tight')
plt.show()

# %%
ax = sns.scatterplot(x='statement_len',
                y='grammar_errors',
                hue='label_score',
                data=df)
ax.set_title("statement length vs grammar errors vs label score")
# Out:
# Text(0.5, 1.0, 'statement length vs grammar errors vs label score')

# %%
df.plot(kind='scatter',
        x='label',
        y='barely_true_counts',
        title='label score vs barely true counts')
# tego typu wykresów nie wrzucać do pracy inżynierskiej
# Out:
# <Axes: title={'center': 'label score vs barely true counts'}, xlabel='label', ylabel='barely_true_counts'>

# %%
ax = sns.scatterplot(x='grammar_errors',
                     y='punctuations',
                     hue='label_score',
                     data=df)
ax.set_title("grammar errors vs punctuations vs label score")
# Out:
# Text(0.5, 1.0, 'grammar errors vs punctuations vs label score')

# %%
ax = df.groupby("label", observed=True)["punctuations"] \
    .mean() \
    .reindex(custom_order) \
    .plot(kind="barh")

ax.set_xlabel("Mean punctuations")
ax.set_title("Mean punctuations per label")
# Out:
# Text(0.5, 1.0, 'Mean punctuations per label')

# %%
sns.pairplot(df,
             vars=[
                 'barely_true_counts',
                 'false_counts',
                 'half_true_counts',
                 'mostly_true_counts',
                 'pants_on_fire_counts'
             ],
             hue='label')
plt.show()

# %%
sns.pairplot(df,
             vars=[
                 'statement_wc',
                 'punctuations',
                 'grammar_errors'
             ],
             hue='label')
plt.show()

# %%
df.groupby(["label", "sentiment"]).size()
# Out:
# label        sentiment
# barely-true  negative      838
#              neutral      1123
#              positive      147
# false        negative      923
#              neutral      1430
#              positive      158
# half-true    negative     1000
#              neutral      1368
#              positive      270
# mostly-true  negative      893
#              neutral      1330
#              positive      243
# pants-fire   negative      442
#              neutral       563
#              positive       45
# true         negative      725
#              neutral      1143
#              positive      195
# dtype: int64

# %%
df.groupby(["label", "sentiment"]).size().unstack()
# Out:
# sentiment    negative  neutral  positive
# label
# barely-true       838     1123       147
# false             923     1430       158
# half-true        1000     1368       270
# mostly-true       893     1330       243
# pants-fire        442      563        45
# true              725     1143       195

# %% [markdown]
# ### Zestawienie kolumn label vs sentiment (6 klas decyzyjnych)

# %%
ax = sns.countplot(data=df, x="label", hue="sentiment", order=custom_order)
#ax.set_title("Zestawienie kolumn label vs sentiment (6 klas decyzyjnych)")
ax.set_ylabel("Liczba przykładów")
ax.set_xlabel("Kolumna label")

plt.savefig("../imgs/label_vs_sentiment_6way.png")
plt.show()

# %% [markdown]
# ### Zestawienie kolumn bin_label vs sentiment (2 klasy decyzyjne)

# %%
ax = sns.countplot(data=df, x="bin_label", hue="sentiment")
#ax.set_title("Zestawienie kolumn bin_label vs sentiment (2 klasy decyzyjne)")
ax.set_ylabel("Liczba przykładów")
ax.set_xlabel("Kolumna bin_label")

plt.savefig("../imgs/label_vs_sentiment_2way.png")
plt.show()

# %%
df_numeric = df.select_dtypes(include='number')
correlation_matrix = df_numeric.corr()
correlation_matrix
# Out:
#                           barely_true_counts  false_counts  half_true_counts  \
# barely_true_counts                  1.000000      0.921644          0.912453
# false_counts                        0.921644      1.000000          0.756226
# half_true_counts                    0.912453      0.756226          1.000000
# mostly_true_counts                  0.881843      0.709154          0.987608
# pants_on_fire_counts                0.422520      0.651688          0.215158
# grammar_errors                     -0.021559     -0.006917         -0.034589
# ratio_of_capital_letters            0.000582      0.022668         -0.028344
# statement_len                      -0.046585     -0.037769         -0.036908
# justification_len                   0.038891      0.035050          0.024931
# statement_wc                       -0.031861     -0.024282         -0.021197
# justification_wc                    0.035483      0.032856          0.021972
# articles_wc                         0.002932     -0.014312          0.016024
# label_score                         0.003799     -0.068412          0.070434
# punctuations                        0.036380      0.035105          0.035890
# statement_word_count               -0.031861     -0.024282         -0.021197
# justification_word_count            0.035483      0.032856          0.021972
# articles_word_count                 0.002932     -0.014312          0.016024
#
#                           mostly_true_counts  pants_on_fire_counts  \
# barely_true_counts                  0.881843              0.422520
# false_counts                        0.709154              0.651688
# half_true_counts                    0.987608              0.215158
# mostly_true_counts                  1.000000              0.155640
# pants_on_fire_counts                0.155640              1.000000
# grammar_errors                     -0.037016              0.004071
# ratio_of_capital_letters           -0.036594              0.082208
# statement_len                      -0.032031             -0.012112
# justification_len                   0.023235              0.015906
# statement_wc                       -0.016829             -0.006342
# justification_wc                    0.020400              0.017547
# articles_wc                         0.021218             -0.036802
# label_score                         0.088104             -0.202329
# punctuations                        0.037600              0.018480
# statement_word_count               -0.016829             -0.006342
# justification_word_count            0.020400              0.017547
# articles_word_count                 0.021218             -0.036802
#
#                           grammar_errors  ratio_of_capital_letters  \
# barely_true_counts             -0.021559                  0.000582
# false_counts                   -0.006917                  0.022668
# half_true_counts               -0.034589                 -0.028344
# mostly_true_counts             -0.037016                 -0.036594
# pants_on_fire_counts            0.004071                  0.082208
# grammar_errors                  1.000000                  0.054476
# ratio_of_capital_letters        0.054476                  1.000000
# statement_len                   0.195473                 -0.257531
# justification_len              -0.000017                  0.010124
# statement_wc                    0.193583                 -0.260625
# justification_wc                0.000142                  0.005912
# articles_wc                    -0.049720                 -0.069876
# label_score                    -0.047352                 -0.108659
# punctuations                    0.032527                  0.061855
# statement_word_count            0.193583                 -0.260625
# justification_word_count        0.000142                  0.005912
# articles_word_count            -0.049720                 -0.069876
#
#                           statement_len  justification_len  statement_wc  \
# barely_true_counts            -0.046585           0.038891     -0.031861
# false_counts                  -0.037769           0.035050     -0.024282
# half_true_counts              -0.036908           0.024931     -0.021197
# mostly_true_counts            -0.032031           0.023235     -0.016829
# pants_on_fire_counts          -0.012112           0.015906     -0.006342
# grammar_errors                 0.195473          -0.000017      0.193583
# ratio_of_capital_letters      -0.257531           0.010124     -0.260625
# statement_len                  1.000000           0.018893      0.968455
# justification_len              0.018893           1.000000      0.020998
# statement_wc                   0.968455           0.020998      1.000000
# justification_wc               0.015764           0.920295      0.018941
# articles_wc                   -0.022087          -0.024016     -0.021528
# label_score                    0.045139           0.003853      0.057920
# punctuations                   0.014643           0.009351      0.016659
# statement_word_count           0.968455           0.020998      1.000000
# justification_word_count       0.015764           0.920295      0.018941
# articles_word_count           -0.022087          -0.024016     -0.021528
#
#                           justification_wc  articles_wc  label_score  \
# barely_true_counts                0.035483     0.002932     0.003799
# false_counts                      0.032856    -0.014312    -0.068412
# half_true_counts                  0.021972     0.016024     0.070434
# mostly_true_counts                0.020400     0.021218     0.088104
# pants_on_fire_counts              0.017547    -0.036802    -0.202329
# grammar_errors                    0.000142    -0.049720    -0.047352
# ratio_of_capital_letters          0.005912    -0.069876    -0.108659
# statement_len                     0.015764    -0.022087     0.045139
# justification_len                 0.920295    -0.024016     0.003853
# statement_wc                      0.018941    -0.021528     0.057920
# justification_wc                  1.000000    -0.035475     0.002708
# articles_wc                      -0.035475     1.000000     0.043375
# label_score                       0.002708     0.043375     1.000000
# punctuations                      0.004481    -0.096390     0.028820
# statement_word_count              0.018941    -0.021528     0.057920
# justification_word_count          1.000000    -0.035475     0.002708
# articles_word_count              -0.035475     1.000000     0.043375
#
#                           punctuations  statement_word_count  \
# barely_true_counts            0.036380             -0.031861
# false_counts                  0.035105             -0.024282
# half_true_counts              0.035890             -0.021197
# mostly_true_counts            0.037600             -0.016829
# pants_on_fire_counts          0.018480             -0.006342
# grammar_errors                0.032527              0.193583
# ratio_of_capital_letters      0.061855             -0.260625
# statement_len                 0.014643              0.968455
# justification_len             0.009351              0.020998
# statement_wc                  0.016659              1.000000
# justification_wc              0.004481              0.018941
# articles_wc                  -0.096390             -0.021528
# label_score                   0.028820              0.057920
# punctuations                  1.000000              0.016659
# statement_word_count          0.016659              1.000000
# justification_word_count      0.004481              0.018941
# articles_word_count          -0.096390             -0.021528
#
#                           justification_word_count  articles_word_count
# barely_true_counts                        0.035483             0.002932
# false_counts                              0.032856            -0.014312
# half_true_counts                          0.021972             0.016024
# mostly_true_counts                        0.020400             0.021218
# pants_on_fire_counts                      0.017547            -0.036802
# grammar_errors                            0.000142            -0.049720
# ratio_of_capital_letters                  0.005912            -0.069876
# statement_len                             0.015764            -0.022087
# justification_len                         0.920295            -0.024016
# statement_wc                              0.018941            -0.021528
# justification_wc                          1.000000            -0.035475
# articles_wc                              -0.035475             1.000000
# label_score                               0.002708             0.043375
# punctuations                              0.004481            -0.096390
# statement_word_count                      0.018941            -0.021528
# justification_word_count                  1.000000            -0.035475
# articles_word_count                      -0.035475             1.000000

# %%
# Wybieramy tylko kolumny liczbowe (podstawowo wybiera też tekstowe i próbuje przekonwertować)
df_numeric = df.select_dtypes(include='number')
corr_matrix = df_numeric.corr()

# Ustal próg korelacji
threshold = 0.2

# Przechodzimy przez górny trójkąt macierzy korelacji, pomijając przekątną
high_corr = []

for i in range(len(corr_matrix.columns)):
    for j in range(i + 1, len(corr_matrix.columns)):
        col1 = corr_matrix.columns[i]
        col2 = corr_matrix.columns[j]
        corr_value = corr_matrix.iloc[i, j]
        if abs(corr_value) > threshold:
            high_corr.append((col1, col2, corr_value))

# Wyświetlenie wyników
for col1, col2, value in high_corr:
    print(f"{col1} vs {col2}: korelacja = {value:.3f}")
# Out:
# barely_true_counts vs false_counts: korelacja = 0.922
# barely_true_counts vs half_true_counts: korelacja = 0.912
# barely_true_counts vs mostly_true_counts: korelacja = 0.882
# barely_true_counts vs pants_on_fire_counts: korelacja = 0.423
# false_counts vs half_true_counts: korelacja = 0.756
# false_counts vs mostly_true_counts: korelacja = 0.709
# false_counts vs pants_on_fire_counts: korelacja = 0.652
# half_true_counts vs mostly_true_counts: korelacja = 0.988
# half_true_counts vs pants_on_fire_counts: korelacja = 0.215
# pants_on_fire_counts vs label_score: korelacja = -0.202
# ratio_of_capital_letters vs statement_len: korelacja = -0.258
# ratio_of_capital_letters vs statement_wc: korelacja = -0.261
# ratio_of_capital_letters vs statement_word_count: korelacja = -0.261
# statement_len vs statement_wc: korelacja = 0.968
# statement_len vs statement_word_count: korelacja = 0.968
# justification_len vs justification_wc: korelacja = 0.920
# justification_len vs justification_word_count: korelacja = 0.920
# statement_wc vs statement_word_count: korelacja = 1.000
# justification_wc vs justification_word_count: korelacja = 1.000
# articles_wc vs articles_word_count: korelacja = 1.000
